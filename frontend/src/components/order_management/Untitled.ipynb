# %%
import pandas as pd

# %%
json = pd.read_json('MOCK_DATA.json')

# %%
json
# Out:
#      order_id   product       date            customer  total  \
# 0           1  Motorola 2022-01-11      Merline Docket  98.07
# 1           2     Telit 2024-09-02         Birk Iddins   5.34
# 2           3   Infinix 2023-07-25     Glendon Stiegar  33.64
# 3           4     Spice 2022-02-08     Huberto Pessold  85.66
# 4           5   Samsung 2024-07-01        Meryl Perryn  91.29
# ..        ...       ...        ...                 ...    ...
# 195       196  i-mobile 2023-09-17  Evangelina Bittany  21.78
# 196       197   Samsung 2023-06-25      Averil Brunker   3.57
# 197       198      Sony 2023-01-19       Trixie Heaphy   7.27
# 198       199    Xiaomi 2023-06-14  Johnathon Kmieciak   7.54
# 199       200       BLU 2023-10-11        Oliy Boulter  77.12
#
#                  payment  status  action
# 0                  laser       3       2
# 1                maestro       2       1
# 2                    jcb       4       2
# 3             mastercard       3       2
# ...

# %%
json = json.drop(json['action'])

# %%
json
# Out:
#      order_id   product       date            customer  total  \
# 0           1  Motorola 2022-01-11      Merline Docket  98.07
# 4           5   Samsung 2024-07-01        Meryl Perryn  91.29
# 5           6     Apple 2023-02-01    Diandra Le Gallo  84.71
# 6           7     Spice 2024-01-17  Sheffield Maffucci  97.99
# 7           8  Micromax 2022-08-22    Coral Lightoller  50.05
# ..        ...       ...        ...                 ...    ...
# 195       196  i-mobile 2023-09-17  Evangelina Bittany  21.78
# 196       197   Samsung 2023-06-25      Averil Brunker   3.57
# 197       198      Sony 2023-01-19       Trixie Heaphy   7.27
# 198       199    Xiaomi 2023-06-14  Johnathon Kmieciak   7.54
# 199       200       BLU 2023-10-11        Oliy Boulter  77.12
#
#                  payment  status  action
# 0                  laser       3       2
# 4                    jcb       2       2
# 5                    jcb       1       3
# 6                    jcb       3       1
# ...

# %%
json = json.drop('action', axis=1)

# %%
json
# Out:
#      order_id   product       date            customer  total  \
# 0           1  Motorola 2022-01-11      Merline Docket  98.07
# 1           2     Telit 2024-09-02         Birk Iddins   5.34
# 2           3   Infinix 2023-07-25     Glendon Stiegar  33.64
# 3           4     Spice 2022-02-08     Huberto Pessold  85.66
# 4           5   Samsung 2024-07-01        Meryl Perryn  91.29
# ..        ...       ...        ...                 ...    ...
# 195       196  i-mobile 2023-09-17  Evangelina Bittany  21.78
# 196       197   Samsung 2023-06-25      Averil Brunker   3.57
# 197       198      Sony 2023-01-19       Trixie Heaphy   7.27
# 198       199    Xiaomi 2023-06-14  Johnathon Kmieciak   7.54
# 199       200       BLU 2023-10-11        Oliy Boulter  77.12
#
#                  payment  status
# 0                  laser       3
# 1                maestro       2
# 2                    jcb       4
# 3             mastercard       3
# 4                    jcb       2
# ...

# %%
json.to_json('cleaned_data.json', orient='records')
